# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %% [markdown]
# ### useful for imshow ans other plots that return atrists, not for scatter that returns path collections

# %%
# %matplotlib widget

# %%
fig = plt.figure()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def f(x, y):
    return np.sin(x) + np.cos(y)

# %%
x = np.linspace(0, 2 * np.pi, 120)
y = np.linspace(0, 2 * np.pi, 100).reshape(-1, 1)

# %%
# ims is a list of lists, each row is a list of artists to draw in the
# current frame; here we are just animating one artist, the image, in
# each frame
ims = []
for i in range(60):
    x += np.pi / 15.
    y += np.pi / 20.
    im = plt.imshow(f(x, y), animated=True)
    ims.append([im])

# %%
ani = animation.ArtistAnimation(fig, ims, interval=50, blit=True,
                                repeat_delay=1000)

# %%
ani.save('../animations/dynamic_images.mp4')
#ani.to_html5_video(embed_limit=20)

# %%
from IPython.display import HTML

# %%
HTML(ani.to_html5_video(embed_limit=20))
# Out:
# <video width="1252" height="488" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
plt.show()
